# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://finance.yahoo.com/crypto/?offset=0&count=100'
page=requests.get(url)

soup=BeautifulSoup(page.text, 'html')

# %%
#print(soup)

# %%
#Find the required table
table = soup.find_all('table')
#table

# %%
#Get the details of column headers in table
for row in table:
    column_headers = row.find_all('th') #titles

# %%
#column_headers

# %%
#Split the necessary column titles
column_titles = [title.text.strip() for title in column_headers] 
print(column_titles)
# Out:
# ['Symbol', 'Name', 'Price (Intraday)', 'Change', '% Change', 'Market Cap', 'Volume in Currency (Since 0:00 UTC)', 'Volume in Currency (24Hr)', 'Total Volume All Currencies (24Hr)', 'Circulating Supply', '52 Week Range', 'Day Chart']

# %%
#store the column title to a dataframe
import pandas as pd
data=pd.DataFrame(columns=column_titles)

# %%
data
# Out:
# Empty DataFrame
# Columns: [Symbol, Name, Price (Intraday), Change, % Change, Market Cap, Volume in Currency (Since 0:00 UTC), Volume in Currency (24Hr), Total Volume All Currencies (24Hr), Circulating Supply, 52 Week Range, Day Chart]
# Index: []

# %%
#Gather column data
for t in table: 
    column_data = t.find_all('tr')
    for row in column_data:
        pass
#column_data

# %%
#gather row data
for row in column_data[1:]:
    row_data=row.find_all('td')
    individual_row_data=[data.text.strip() for data in row_data]
    length=len(data)
    data.loc[length] = individual_row_data

# %%
data.head(5)
# Out:
#      Symbol             Name Price (Intraday)     Change % Change Market Cap  \
# 0   BTC-USD      Bitcoin USD        51,816.28  +1,097.47   +2.16%     1.018T
# 1   ETH-USD     Ethereum USD         3,033.10    +112.57   +3.85%   364.445B
# 2  USDT-USD  Tether USDt USD         0.999834  -0.000007   -0.00%    97.894B
# 3   BNB-USD          BNB USD           380.81      +6.42   +1.71%    56.947B
# 4   SOL-USD       Solana USD           103.82      +4.13   +4.14%    45.793B
#
#   Volume in Currency (Since 0:00 UTC) Volume in Currency (24Hr)  \
# 0                              15.54B                    15.54B
# 1                             11.312B                   11.312B
# 2                             33.515B                   33.515B
# 3                              1.079B                    1.079B
# 4                              1.008B                    1.008B
#
#   Total Volume All Currencies (24Hr) Circulating Supply 52 Week Range  \
# 0                             15.54B            19.637M
# 1                            11.312B           120.156M
# 2                            33.515B            97.911B
# 3                             1.079B           149.543M
# 4                             1.008B           441.082M
#
#   Day Chart
# 0
# 1
# 2
# 3
# 4

# %%
#get data of other pages
for outer_row in table:
    nested_table = outer_row.find('table')
    if nested_table:
        nested_rows = nested_table.find_all('tr')
        for nested_row in nested_rows:
            pass
    else:
        pass

# %%
#Gather the new row data of other pages
for row in column_data[1:]:
    row_data=row.find_all('td')
    individual_row_data=[data.text.strip() for data in row_data]
    length=len(data)
    data.loc[length] = individual_row_data

# %%
data.head(50)
# Out:
#           Symbol                   Name Price (Intraday)       Change  \
# 0        BTC-USD            Bitcoin USD        51,816.28    +1,097.47
# 1        ETH-USD           Ethereum USD         3,033.10      +112.57
# 2       USDT-USD        Tether USDt USD         0.999834    -0.000007
# 3        BNB-USD                BNB USD           380.81        +6.42
# 4        SOL-USD             Solana USD           103.82        +4.13
# 5        XRP-USD                XRP USD         0.546746    +0.013019
# 6      STETH-USD    Lido Staked ETH USD         3,024.52      +106.50
# 7       USDC-USD           USD Coin USD         0.999996    +0.000052
# 8        ADA-USD            Cardano USD         0.599085    +0.024340
# 9       AVAX-USD          Avalanche USD            36.84        +1.26
# 10      DOGE-USD           Dogecoin USD         0.086073    +0.001635
# 11       TRX-USD               TRON USD         0.137758    -0.000082
# 12      WTRX-USD       Wrapped TRON USD         0.137248    -0.000643
# 13      LINK-USD          Chainlink USD            18.61        +0.66
# 14       DOT-USD           Polkadot USD           7.8084      +0.2677
# 15     MATIC-USD            Polygon USD         0.997445    +0.010174
# 16      WBTC-USD    Wrapped Bitcoin USD        51,744.31    +1,045.29
# 17  TON11419-USD            Toncoin USD           2.1071      +0.0307
# 18   UNI7083-USD            Uniswap USD            11.22        -0.94
# 19       ICP-USD  Internet Computer USD            12.58        +0.38
# 20      SHIB-USD          Shiba Inu USD       0.00000966  +0.00000026
# 21       DAI-USD                Dai USD         0.999993    -0.000019
# 22       BCH-USD       Bitcoin Cash USD           269.22        +3.45
# 23       LTC-USD           Litecoin USD            70.44        +1.18
# 24  IMX10603-USD          Immutable USD           3.0775      +0.0938
# 25       BTC-USD            Bitcoin USD        51,816.28    +1,097.47
# 26       ETH-USD           Ethereum USD         3,033.10      +112.57
# 27      USDT-USD        Tether USDt USD         0.999834    -0.000007
# 28       BNB-USD                BNB USD           380.81        +6.42
# 29       SOL-USD             Solana USD           103.82        +4.13
# 30       XRP-USD                XRP USD         0.546746    +0.013019
# 31     STETH-USD    Lido Staked ETH USD         3,024.52      +106.50
# 32      USDC-USD           USD Coin USD         0.999996    +0.000052
# 33       ADA-USD            Cardano USD         0.599085    +0.024340
# 34      AVAX-USD          Avalanche USD            36.84        +1.26
# 35      DOGE-USD           Dogecoin USD         0.086073    +0.001635
# 36       TRX-USD               TRON USD         0.137758    -0.000082
# 37      WTRX-USD       Wrapped TRON USD         0.137248    -0.000643
# 38      LINK-USD          Chainlink USD            18.61        +0.66
# 39       DOT-USD           Polkadot USD           7.8084      +0.2677
# 40     MATIC-USD            Polygon USD         0.997445    +0.010174
# 41      WBTC-USD    Wrapped Bitcoin USD        51,744.31    +1,045.29
# 42  TON11419-USD            Toncoin USD           2.1071      +0.0307
# 43   UNI7083-USD            Uniswap USD            11.22        -0.94
# 44       ICP-USD  Internet Computer USD            12.58        +0.38
# 45      SHIB-USD          Shiba Inu USD       0.00000966  +0.00000026
# 46       DAI-USD                Dai USD         0.999993    -0.000019
# 47       BCH-USD       Bitcoin Cash USD           269.22        +3.45
# 48       LTC-USD           Litecoin USD            70.44        +1.18
# 49  IMX10603-USD          Immutable USD           3.0775      +0.0938
#
#    % Change Market Cap Volume in Currency (Since 0:00 UTC)  \
# 0    +2.16%     1.018T                              15.54B
# 1    +3.85%   364.445B                             11.312B
# 2    -0.00%    97.894B                             33.515B
# 3    +1.71%    56.947B                              1.079B
# 4    +4.14%    45.793B                              1.008B
# 5    +2.44%    29.849B                            686.578M
# 6    +3.65%    29.655B                             22.773M
# 7    +0.01%    28.148B                              3.014B
# 8    +4.23%     21.25B                            371.785M
# 9    +3.56%    13.894B                            334.856M
# 10   +1.94%    12.327B                            302.652M
# 11   -0.06%    12.124B                            206.352M
# 12   -0.47%    12.079B                             786,977
# 13   +3.70%    10.927B                            265.376M
# 14   +3.55%    10.057B                            229.968M
# 15   +1.03%     9.594B                            404.421M
# 16   +2.06%     8.127B                            126.157M
# 17   +1.48%     7.306B                             31.136M
# 18   -7.73%     6.712B                              1.137B
# 19   +3.15%     5.779B                             98.316M
# 20   +2.77%      5.69B                            112.842M
# 21   -0.00%     5.348B                            108.831M
# 22   +1.30%     5.291B                            148.724M
# 23   +1.70%      5.23B                            238.414M
# 24   +3.14%     4.275B                             83.066M
# 25   +2.16%     1.018T                              15.54B
# 26   +3.85%   364.445B                             11.312B
# 27   -0.00%    97.894B                             33.515B
# 28   +1.71%    56.947B                              1.079B
# 29   +4.14%    45.793B                              1.008B
# 30   +2.44%    29.849B                            686.578M
# 31   +3.65%    29.655B                             22.773M
# 32   +0.01%    28.148B                              3.014B
# 33   +4.23%     21.25B                            371.785M
# 34   +3.56%    13.894B                            334.856M
# 35   +1.94%    12.327B                            302.652M
# 36   -0.06%    12.124B                            206.352M
# 37   -0.47%    12.079B                             786,977
# 38   +3.70%    10.927B                            265.376M
# 39   +3.55%    10.057B                            229.968M
# 40   +1.03%     9.594B                            404.421M
# 41   +2.06%     8.127B                            126.157M
# 42   +1.48%     7.306B                             31.136M
# 43   -7.73%     6.712B                              1.137B
# 44   +3.15%     5.779B                             98.316M
# 45   +2.77%      5.69B                            112.842M
# 46   -0.00%     5.348B                            108.831M
# 47   +1.30%     5.291B                            148.724M
# 48   +1.70%      5.23B                            238.414M
# 49   +3.14%     4.275B                             83.066M
#
#    Volume in Currency (24Hr) Total Volume All Currencies (24Hr)  \
# 0                     15.54B                             15.54B
# 1                    11.312B                            11.312B
# 2                    33.515B                            33.515B
# 3                     1.079B                             1.079B
# 4                     1.008B                             1.008B
# 5                   686.578M                           686.578M
# 6                    22.773M                            22.773M
# 7                     3.014B                             3.014B
# 8                   371.785M                           371.785M
# 9                   334.856M                           334.856M
# 10                  302.652M                           302.652M
# 11                  206.352M                           206.352M
# 12                   786,977                            786,977
# 13                  265.376M                           265.376M
# 14                  229.968M                           229.968M
# 15                  404.421M                           404.421M
# 16                  126.157M                           126.157M
# 17                   31.136M                            31.136M
# 18                    1.137B                             1.137B
# 19                   98.316M                            98.316M
# 20                  112.842M                           112.842M
# 21                  108.831M                           108.831M
# 22                  148.724M                           148.724M
# 23                  238.414M                           238.414M
# 24                   83.066M                            83.066M
# 25                    15.54B                             15.54B
# 26                   11.312B                            11.312B
# 27                   33.515B                            33.515B
# 28                    1.079B                             1.079B
# 29                    1.008B                             1.008B
# 30                  686.578M                           686.578M
# 31                   22.773M                            22.773M
# 32                    3.014B                             3.014B
# 33                  371.785M                           371.785M
# 34                  334.856M                           334.856M
# 35                  302.652M                           302.652M
# 36                  206.352M                           206.352M
# 37                   786,977                            786,977
# 38                  265.376M                           265.376M
# 39                  229.968M                           229.968M
# 40                  404.421M                           404.421M
# 41                  126.157M                           126.157M
# 42                   31.136M                            31.136M
# 43                    1.137B                             1.137B
# 44                   98.316M                            98.316M
# 45                  112.842M                           112.842M
# 46                  108.831M                           108.831M
# 47                  148.724M                           148.724M
# 48                  238.414M                           238.414M
# 49                   83.066M                            83.066M
#
#    Circulating Supply 52 Week Range Day Chart
# 0             19.637M
# 1            120.156M
# 2             97.911B
# 3            149.543M
# 4            441.082M
# 5             54.594B
# 6              9.805M
# 7             28.148B
# 8              35.47B
# 9            377.172M
# 10           143.213B
# 11            88.013B
# 12            88.012B
# 13             587.1M
# 14             1.288B
# 15             9.618B
# 16            157,061
# 17             3.467B
# 18           598.187M
# 19           459.377M
# 20            589.29T
# 21             5.348B
# 22            19.651M
# 23            74.243M
# 24             1.389B
# 25            19.637M
# 26           120.156M
# 27            97.911B
# 28           149.543M
# 29           441.082M
# 30            54.594B
# 31             9.805M
# 32            28.148B
# 33             35.47B
# 34           377.172M
# 35           143.213B
# 36            88.013B
# 37            88.012B
# 38             587.1M
# 39             1.288B
# 40             9.618B
# 41            157,061
# 42             3.467B
# 43           598.187M
# 44           459.377M
# 45            589.29T
# 46             5.348B
# 47            19.651M
# 48            74.243M
# 49             1.389B

# %%
#drop irrelevant axes
data.drop(['52 Week Range','Day Chart'], axis=1, inplace=True)

# %%
data.to_csv(r'/Users/apple/Desktop/webscrape_of_crypto_cleaned.csv', index=False)

# %%
def currency_converter(value):
    value_str = str(value).strip().upper().replace(',', '')  # Remove commas and convert to uppercase

    if value_str.endswith('B'):
        numeric_part = float(value_str[:-1])  # Remove 'B' and convert to float
        return numeric_part * 1e9  # Convert billion to units
    elif value_str.endswith('T'):
        numeric_part = float(value_str[:-1])
        return numeric_part * 1e12  # Convert trillion to units
    elif value_str.endswith('M'):
        numeric_part = float(value_str[:-1])
        return numeric_part * 1e6  # Convert million to units
    else:
        numeric_part = float(value_str)
        return numeric_part   # Return normal units


data['Market Cap'] = data['Market Cap'].apply(currency_converter)
data['Volume in Currency (Since 0:00 UTC)'] = data['Volume in Currency (Since 0:00 UTC)'].apply(currency_converter)
data['Volume in Currency (24Hr)'] = data['Volume in Currency (24Hr)'].apply(currency_converter)
data['Total Volume All Currencies (24Hr)'] = data['Total Volume All Currencies (24Hr)'].apply(currency_converter)
data['Circulating Supply'] = data['Circulating Supply'].apply(currency_converter)
data['% Change'] = data['% Change'].str.replace('%', '')

# %%
data
# Out:
#           Symbol                   Name Price (Intraday)       Change  \
# 0        BTC-USD            Bitcoin USD        51,816.28    +1,097.47
# 1        ETH-USD           Ethereum USD         3,033.10      +112.57
# 2       USDT-USD        Tether USDt USD         0.999834    -0.000007
# 3        BNB-USD                BNB USD           380.81        +6.42
# 4        SOL-USD             Solana USD           103.82        +4.13
# 5        XRP-USD                XRP USD         0.546746    +0.013019
# 6      STETH-USD    Lido Staked ETH USD         3,024.52      +106.50
# 7       USDC-USD           USD Coin USD         0.999996    +0.000052
# 8        ADA-USD            Cardano USD         0.599085    +0.024340
# 9       AVAX-USD          Avalanche USD            36.84        +1.26
# 10      DOGE-USD           Dogecoin USD         0.086073    +0.001635
# 11       TRX-USD               TRON USD         0.137758    -0.000082
# 12      WTRX-USD       Wrapped TRON USD         0.137248    -0.000643
# 13      LINK-USD          Chainlink USD            18.61        +0.66
# 14       DOT-USD           Polkadot USD           7.8084      +0.2677
# 15     MATIC-USD            Polygon USD         0.997445    +0.010174
# 16      WBTC-USD    Wrapped Bitcoin USD        51,744.31    +1,045.29
# 17  TON11419-USD            Toncoin USD           2.1071      +0.0307
# 18   UNI7083-USD            Uniswap USD            11.22        -0.94
# 19       ICP-USD  Internet Computer USD            12.58        +0.38
# 20      SHIB-USD          Shiba Inu USD       0.00000966  +0.00000026
# 21       DAI-USD                Dai USD         0.999993    -0.000019
# 22       BCH-USD       Bitcoin Cash USD           269.22        +3.45
# 23       LTC-USD           Litecoin USD            70.44        +1.18
# 24  IMX10603-USD          Immutable USD           3.0775      +0.0938
# 25       BTC-USD            Bitcoin USD        51,816.28    +1,097.47
# 26       ETH-USD           Ethereum USD         3,033.10      +112.57
# 27      USDT-USD        Tether USDt USD         0.999834    -0.000007
# 28       BNB-USD                BNB USD           380.81        +6.42
# 29       SOL-USD             Solana USD           103.82        +4.13
# 30       XRP-USD                XRP USD         0.546746    +0.013019
# 31     STETH-USD    Lido Staked ETH USD         3,024.52      +106.50
# 32      USDC-USD           USD Coin USD         0.999996    +0.000052
# 33       ADA-USD            Cardano USD         0.599085    +0.024340
# 34      AVAX-USD          Avalanche USD            36.84        +1.26
# 35      DOGE-USD           Dogecoin USD         0.086073    +0.001635
# 36       TRX-USD               TRON USD         0.137758    -0.000082
# 37      WTRX-USD       Wrapped TRON USD         0.137248    -0.000643
# 38      LINK-USD          Chainlink USD            18.61        +0.66
# 39       DOT-USD           Polkadot USD           7.8084      +0.2677
# 40     MATIC-USD            Polygon USD         0.997445    +0.010174
# 41      WBTC-USD    Wrapped Bitcoin USD        51,744.31    +1,045.29
# 42  TON11419-USD            Toncoin USD           2.1071      +0.0307
# 43   UNI7083-USD            Uniswap USD            11.22        -0.94
# 44       ICP-USD  Internet Computer USD            12.58        +0.38
# 45      SHIB-USD          Shiba Inu USD       0.00000966  +0.00000026
# 46       DAI-USD                Dai USD         0.999993    -0.000019
# 47       BCH-USD       Bitcoin Cash USD           269.22        +3.45
# 48       LTC-USD           Litecoin USD            70.44        +1.18
# 49  IMX10603-USD          Immutable USD           3.0775      +0.0938
#
#    % Change    Market Cap  Volume in Currency (Since 0:00 UTC)  \
# 0     +2.16  1.018000e+12                         1.554000e+10
# 1     +3.85  3.644450e+11                         1.131200e+10
# 2     -0.00  9.789400e+10                         3.351500e+10
# 3     +1.71  5.694700e+10                         1.079000e+09
# 4     +4.14  4.579300e+10                         1.008000e+09
# 5     +2.44  2.984900e+10                         6.865780e+08
# 6     +3.65  2.965500e+10                         2.277300e+07
# 7     +0.01  2.814800e+10                         3.014000e+09
# 8     +4.23  2.125000e+10                         3.717850e+08
# 9     +3.56  1.389400e+10                         3.348560e+08
# 10    +1.94  1.232700e+10                         3.026520e+08
# 11    -0.06  1.212400e+10                         2.063520e+08
# 12    -0.47  1.207900e+10                         7.869770e+05
# 13    +3.70  1.092700e+10                         2.653760e+08
# 14    +3.55  1.005700e+10                         2.299680e+08
# 15    +1.03  9.594000e+09                         4.044210e+08
# 16    +2.06  8.127000e+09                         1.261570e+08
# 17    +1.48  7.306000e+09                         3.113600e+07
# 18    -7.73  6.712000e+09                         1.137000e+09
# 19    +3.15  5.779000e+09                         9.831600e+07
# 20    +2.77  5.690000e+09                         1.128420e+08
# 21    -0.00  5.348000e+09                         1.088310e+08
# 22    +1.30  5.291000e+09                         1.487240e+08
# 23    +1.70  5.230000e+09                         2.384140e+08
# 24    +3.14  4.275000e+09                         8.306600e+07
# 25    +2.16  1.018000e+12                         1.554000e+10
# 26    +3.85  3.644450e+11                         1.131200e+10
# 27    -0.00  9.789400e+10                         3.351500e+10
# 28    +1.71  5.694700e+10                         1.079000e+09
# 29    +4.14  4.579300e+10                         1.008000e+09
# 30    +2.44  2.984900e+10                         6.865780e+08
# 31    +3.65  2.965500e+10                         2.277300e+07
# 32    +0.01  2.814800e+10                         3.014000e+09
# 33    +4.23  2.125000e+10                         3.717850e+08
# 34    +3.56  1.389400e+10                         3.348560e+08
# 35    +1.94  1.232700e+10                         3.026520e+08
# 36    -0.06  1.212400e+10                         2.063520e+08
# 37    -0.47  1.207900e+10                         7.869770e+05
# 38    +3.70  1.092700e+10                         2.653760e+08
# 39    +3.55  1.005700e+10                         2.299680e+08
# 40    +1.03  9.594000e+09                         4.044210e+08
# 41    +2.06  8.127000e+09                         1.261570e+08
# 42    +1.48  7.306000e+09                         3.113600e+07
# 43    -7.73  6.712000e+09                         1.137000e+09
# 44    +3.15  5.779000e+09                         9.831600e+07
# 45    +2.77  5.690000e+09                         1.128420e+08
# 46    -0.00  5.348000e+09                         1.088310e+08
# 47    +1.30  5.291000e+09                         1.487240e+08
# 48    +1.70  5.230000e+09                         2.384140e+08
# 49    +3.14  4.275000e+09                         8.306600e+07
#
#     Volume in Currency (24Hr)  Total Volume All Currencies (24Hr)  \
# 0                1.554000e+10                        1.554000e+10
# 1                1.131200e+10                        1.131200e+10
# 2                3.351500e+10                        3.351500e+10
# 3                1.079000e+09                        1.079000e+09
# 4                1.008000e+09                        1.008000e+09
# 5                6.865780e+08                        6.865780e+08
# 6                2.277300e+07                        2.277300e+07
# 7                3.014000e+09                        3.014000e+09
# 8                3.717850e+08                        3.717850e+08
# 9                3.348560e+08                        3.348560e+08
# 10               3.026520e+08                        3.026520e+08
# 11               2.063520e+08                        2.063520e+08
# 12               7.869770e+05                        7.869770e+05
# 13               2.653760e+08                        2.653760e+08
# 14               2.299680e+08                        2.299680e+08
# 15               4.044210e+08                        4.044210e+08
# 16               1.261570e+08                        1.261570e+08
# 17               3.113600e+07                        3.113600e+07
# 18               1.137000e+09                        1.137000e+09
# 19               9.831600e+07                        9.831600e+07
# 20               1.128420e+08                        1.128420e+08
# 21               1.088310e+08                        1.088310e+08
# 22               1.487240e+08                        1.487240e+08
# 23               2.384140e+08                        2.384140e+08
# 24               8.306600e+07                        8.306600e+07
# 25               1.554000e+10                        1.554000e+10
# 26               1.131200e+10                        1.131200e+10
# 27               3.351500e+10                        3.351500e+10
# 28               1.079000e+09                        1.079000e+09
# 29               1.008000e+09                        1.008000e+09
# 30               6.865780e+08                        6.865780e+08
# 31               2.277300e+07                        2.277300e+07
# 32               3.014000e+09                        3.014000e+09
# 33               3.717850e+08                        3.717850e+08
# 34               3.348560e+08                        3.348560e+08
# 35               3.026520e+08                        3.026520e+08
# 36               2.063520e+08                        2.063520e+08
# 37               7.869770e+05                        7.869770e+05
# 38               2.653760e+08                        2.653760e+08
# 39               2.299680e+08                        2.299680e+08
# 40               4.044210e+08                        4.044210e+08
# 41               1.261570e+08                        1.261570e+08
# 42               3.113600e+07                        3.113600e+07
# 43               1.137000e+09                        1.137000e+09
# 44               9.831600e+07                        9.831600e+07
# 45               1.128420e+08                        1.128420e+08
# 46               1.088310e+08                        1.088310e+08
# 47               1.487240e+08                        1.487240e+08
# 48               2.384140e+08                        2.384140e+08
# 49               8.306600e+07                        8.306600e+07
#
#     Circulating Supply
# 0         1.963700e+07
# 1         1.201560e+08
# 2         9.791100e+10
# 3         1.495430e+08
# 4         4.410820e+08
# 5         5.459400e+10
# 6         9.805000e+06
# 7         2.814800e+10
# 8         3.547000e+10
# 9         3.771720e+08
# 10        1.432130e+11
# 11        8.801300e+10
# 12        8.801200e+10
# 13        5.871000e+08
# 14        1.288000e+09
# 15        9.618000e+09
# 16        1.570610e+05
# 17        3.467000e+09
# 18        5.981870e+08
# 19        4.593770e+08
# 20        5.892900e+14
# 21        5.348000e+09
# 22        1.965100e+07
# 23        7.424300e+07
# 24        1.389000e+09
# 25        1.963700e+07
# 26        1.201560e+08
# 27        9.791100e+10
# 28        1.495430e+08
# 29        4.410820e+08
# 30        5.459400e+10
# 31        9.805000e+06
# 32        2.814800e+10
# 33        3.547000e+10
# 34        3.771720e+08
# 35        1.432130e+11
# 36        8.801300e+10
# 37        8.801200e+10
# 38        5.871000e+08
# 39        1.288000e+09
# 40        9.618000e+09
# 41        1.570610e+05
# 42        3.467000e+09
# 43        5.981870e+08
# 44        4.593770e+08
# 45        5.892900e+14
# 46        5.348000e+09
# 47        1.965100e+07
# 48        7.424300e+07
# 49        1.389000e+09

# %%
data.describe()
# Out:
#          Market Cap  Volume in Currency (Since 0:00 UTC)  \
# count  5.000000e+01                         5.000000e+01
# mean   7.306964e+10                         2.815121e+09
# std    2.075007e+11                         7.307874e+09
# min    4.275000e+09                         7.869770e+05
# 25%    6.712000e+09                         1.128420e+08
# 50%    1.207900e+10                         2.653760e+08
# 75%    2.965500e+10                         1.008000e+09
# max    1.018000e+12                         3.351500e+10
#
#        Volume in Currency (24Hr)  Total Volume All Currencies (24Hr)  \
# count               5.000000e+01                        5.000000e+01
# mean                2.815121e+09                        2.815121e+09
# std                 7.307874e+09                        7.307874e+09
# min                 7.869770e+05                        7.869770e+05
# 25%                 1.128420e+08                        1.128420e+08
# 50%                 2.653760e+08                        2.653760e+08
# 75%                 1.008000e+09                        1.008000e+09
# max                 3.351500e+10                        3.351500e+10
#
#        Circulating Supply
# count        5.000000e+01
# mean         2.359397e+13
# std          1.166446e+14
# min          1.570610e+05
# 25%          1.495430e+08
# 50%          1.288000e+09
# 75%          3.547000e+10
# max          5.892900e+14

# %%
import seaborn as sns
sns.scatterplot(data['Volume in Currency (Since 0:00 UTC)'],data['Market Cap'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Volume in Currency (Since 0:00 UTC)', ylabel='Market Cap'>

# %% [markdown]
# **THE SCATTERPLOT ABOVE HAS OUTLIERS, IT'S BEST TO FIX THEM**

# %%
#USING LOG TRANSFORM TO FIX THE DATA
import numpy as np
a=data['Market Cap']
log_a=np.log(a)
log_a.min()
# Out:
# 22.176049939335133

# %%
b=data['Volume in Currency (Since 0:00 UTC)']
log_b=np.log(b)
log_b.min()
# Out:
# 13.575954302067784

# %% [markdown]
# **IT'S A LINEAR GRAPH, MOST OF THE DATA POINTS ARE CONCENTERATED IN THE LOW MARKET CAP-LOW VOLUME REGION**

# %%
sns.scatterplot(log_a,log_b)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Market Cap', ylabel='Volume in Currency (Since 0:00 UTC)'>

# %% [markdown]
# **TOP-TIER ASSET SELECTOR MODEL, BASED ON LIQUIDITY AND MARKET CAP**

# %%
high_market_cap_threshold = np.percentile(log_a, 60)  # Threshold for high market capitalization, 60th percentile
high_volume_threshold = np.percentile(log_b, 70)  # 70th percentile

# Filter the dataset, based on the thresholds
high_market_cap_high_volume = data[(log_a >= high_market_cap_threshold) & (log_b >= high_volume_threshold)]
high_market_cap_high_volume
# Out:
#       Symbol             Name Price (Intraday)     Change % Change  \
# 0    BTC-USD      Bitcoin USD        51,816.28  +1,097.47    +2.16
# 1    ETH-USD     Ethereum USD         3,033.10    +112.57    +3.85
# 2   USDT-USD  Tether USDt USD         0.999834  -0.000007    -0.00
# 3    BNB-USD          BNB USD           380.81      +6.42    +1.71
# 4    SOL-USD       Solana USD           103.82      +4.13    +4.14
# 5    XRP-USD          XRP USD         0.546746  +0.013019    +2.44
# 7   USDC-USD     USD Coin USD         0.999996  +0.000052    +0.01
# 25   BTC-USD      Bitcoin USD        51,816.28  +1,097.47    +2.16
# 26   ETH-USD     Ethereum USD         3,033.10    +112.57    +3.85
# 27  USDT-USD  Tether USDt USD         0.999834  -0.000007    -0.00
# 28   BNB-USD          BNB USD           380.81      +6.42    +1.71
# 29   SOL-USD       Solana USD           103.82      +4.13    +4.14
# 30   XRP-USD          XRP USD         0.546746  +0.013019    +2.44
# 32  USDC-USD     USD Coin USD         0.999996  +0.000052    +0.01
#
#       Market Cap  Volume in Currency (Since 0:00 UTC)  \
# 0   1.018000e+12                         1.554000e+10
# 1   3.644450e+11                         1.131200e+10
# 2   9.789400e+10                         3.351500e+10
# 3   5.694700e+10                         1.079000e+09
# 4   4.579300e+10                         1.008000e+09
# 5   2.984900e+10                         6.865780e+08
# 7   2.814800e+10                         3.014000e+09
# 25  1.018000e+12                         1.554000e+10
# 26  3.644450e+11                         1.131200e+10
# 27  9.789400e+10                         3.351500e+10
# 28  5.694700e+10                         1.079000e+09
# 29  4.579300e+10                         1.008000e+09
# 30  2.984900e+10                         6.865780e+08
# 32  2.814800e+10                         3.014000e+09
#
#     Volume in Currency (24Hr)  Total Volume All Currencies (24Hr)  \
# 0                1.554000e+10                        1.554000e+10
# 1                1.131200e+10                        1.131200e+10
# 2                3.351500e+10                        3.351500e+10
# 3                1.079000e+09                        1.079000e+09
# 4                1.008000e+09                        1.008000e+09
# 5                6.865780e+08                        6.865780e+08
# 7                3.014000e+09                        3.014000e+09
# 25               1.554000e+10                        1.554000e+10
# 26               1.131200e+10                        1.131200e+10
# 27               3.351500e+10                        3.351500e+10
# 28               1.079000e+09                        1.079000e+09
# 29               1.008000e+09                        1.008000e+09
# 30               6.865780e+08                        6.865780e+08
# 32               3.014000e+09                        3.014000e+09
#
#     Circulating Supply
# 0         1.963700e+07
# 1         1.201560e+08
# 2         9.791100e+10
# 3         1.495430e+08
# 4         4.410820e+08
# 5         5.459400e+10
# 7         2.814800e+10
# 25        1.963700e+07
# 26        1.201560e+08
# 27        9.791100e+10
# 28        1.495430e+08
# 29        4.410820e+08
# 30        5.459400e+10
# 32        2.814800e+10
