# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://finance.yahoo.com/crypto/?offset=0&count=100'
page=requests.get(url)

soup=BeautifulSoup(page.text, 'html')

# %%
#print(soup)

# %%
table = soup.find_all('table')
#table

# %%
#<table class="svelte-vatrz8"><thead><tr class="headers svelte-vatrz8"><th class="svelte-vatrz8">Sector</th><th class="svelte-vatrz8">Market Weight</th><th class="svelte-vatrz8 disappear">Day Return</th><th class="svelte-vatrz8 disappear">YTD Return</th></tr></thead> <tbody><tr class="svelte-vatrz8 selected"><td class="svelte-vatrz8">All Sectors</td> <td class="svelte-vatrz8">100%</td> <td class="disappear positive svelte-vatrz8">0.14%</td> <td class="disappear positive svelte-vatrz8">5.46%</td> </tr><tr class="svelte-vatrz8"><td class="svelte-vatrz8">Technology</td> <td class="svelte-vatrz8">27.39%</td> <td class="disappear negative svelte-vatrz8">-0.11%</td> <td class="disappear positive svelte-vatrz8">9.01%</td> </tr><tr class="svelte-vatrz8"><td class="svelte-vatrz8">Financial Services</td> <td class="svelte-vatrz8">14.52%</td> <td class="disappear positive svelte-vatrz8">0.31%</td> <td class="disappear positive svelte-vatrz8">4.78%</td> </tr><tr class="svelte-vatrz8"><td class="svelte-vatrz8">Healthcare</td> <td class="svelte-vatrz8">11.74%</td> <td class="disappear positive svelte-vatrz8">0.46%</td> <td class="disappear positive svelte-vatrz8">7.11%</td> </tr><tr class="svelte-vatrz8"><td class="svelte-vatrz8">Consumer Cyclical</td> <td class="svelte-vatrz8">11.00%</td> <td class="disappear negative svelte-vatrz8">-0.24%</td> <td class="disappear positive svelte-vatrz8">2.90%</td> </tr><tr class="svelte-vatrz8"><td class="svelte-vatrz8">Industrials</td> <td class="svelte-vatrz8">9.05%</td> <td class="disappear positive svelte-vatrz8">0.66%</td> <td class="disappear positive svelte-vatrz8">3.88%</td> </tr><tr class="svelte-vatrz8"><td class="svelte-vatrz8">Communication Services</td> <td class="svelte-vatrz8">8.56%</td> <td class="disappear negative svelte-vatrz8">-0.06%</td> <td class="disappear positive svelte-vatrz8">9.22%</td> </tr><tr class="svelte-vatrz8"><td class="svelte-vatrz8">Consumer Defensive</td> <td class="svelte-vatrz8">5.60%</td> <td class="disappear positive svelte-vatrz8">0.48%</td> <td class="disappear positive svelte-vatrz8">4.22%</td> </tr><tr class="svelte-vatrz8"><td class="svelte-vatrz8">Energy</td> <td class="svelte-vatrz8">4.88%</td> <td class="disappear negative svelte-vatrz8">-0.37%</td> <td class="disappear positive svelte-vatrz8">1.05%</td> </tr><tr class="svelte-vatrz8"><td class="svelte-vatrz8">Basic Materials</td> <td class="svelte-vatrz8">2.70%</td> <td class="disappear positive svelte-vatrz8">0.66%</td> <td class="disappear negative svelte-vatrz8">-0.96%</td> </tr><tr class="svelte-vatrz8"><td class="svelte-vatrz8">Real Estate</td> <td class="svelte-vatrz8">2.58%</td> <td class="disappear positive svelte-vatrz8">0.05%</td> <td class="disappear negative svelte-vatrz8">-3.33%</td> </tr><tr class="svelte-vatrz8"><td class="svelte-vatrz8">Utilities</td> <td class="svelte-vatrz8">1.98%</td> <td class="disappear positive svelte-vatrz8">0.72%</td> <td class="disappear negative svelte-vatrz8">-2.96%</td> </tr></tbody></table>

# %%
for row in table:
    titles = row.find_all('th')

# %%
#titles

# %%
table_titles = [title.text.strip() for title in titles] 
print(table_titles)
# Out:
# ['Symbol', 'Name', 'Price (Intraday)', 'Change', '% Change', 'Market Cap', 'Volume in Currency (Since 0:00 UTC)', 'Volume in Currency (24Hr)', 'Total Volume All Currencies (24Hr)', 'Circulating Supply', '52 Week Range', 'Day Chart']

# %%
import pandas as pd
data=pd.DataFrame(columns=table_titles)

# %%
data
# Out:
# Empty DataFrame
# Columns: [Symbol, Name, Price (Intraday), Change, % Change, Market Cap, Volume in Currency (Since 0:00 UTC), Volume in Currency (24Hr), Total Volume All Currencies (24Hr), Circulating Supply, 52 Week Range, Day Chart]
# Index: []

# %%
for t in table: 
    column_data = t.find_all('tr')
    for row in column_data:
        pass

# %%
for row in column_data[1:]:
    row_data=row.find_all('td')
    individual_row_data=[data.text.strip() for data in row_data]
    length=len(data)
    data.loc[length] = individual_row_data

# %%
data.head(5)
# Out:
#      Symbol             Name Price (Intraday)   Change % Change Market Cap  \
# 0   BTC-USD      Bitcoin USD        51,605.39  +793.00   +1.56%     1.013T
# 1   ETH-USD     Ethereum USD         2,991.34   +66.01   +2.26%   359.429B
# 2  USDT-USD  Tether USDt USD           1.0000  +0.0003   +0.03%    97.912B
# 3   BNB-USD          BNB USD           382.06    +7.05   +1.88%    57.131B
# 4   SOL-USD       Solana USD           104.15    +4.20   +4.20%    45.937B
#
#   Volume in Currency (Since 0:00 UTC) Volume in Currency (24Hr)  \
# 0                             15.218B                   15.218B
# 1                             10.618B                   10.618B
# 2                             33.978B                   33.978B
# 3                              1.088B                    1.088B
# 4                              1.089B                    1.089B
#
#   Total Volume All Currencies (24Hr) Circulating Supply 52 Week Range  \
# ...

# %%
for outer_row in table:
    nested_table = outer_row.find('table')
    if nested_table:
        nested_rows = nested_table.find_all('tr')
        for nested_row in nested_rows:
            pass
    else:
        pass

# %%
for row in column_data[1:]:
    row_data=row.find_all('td')
    individual_row_data=[data.text.strip() for data in row_data]
    length=len(data)
    data.loc[length] = individual_row_data

# %%
data.head(10)
# Out:
#       Symbol                 Name Price (Intraday)     Change % Change  \
# 0    BTC-USD          Bitcoin USD        51,605.39    +793.00   +1.56%
# 1    ETH-USD         Ethereum USD         2,991.34     +66.01   +2.26%
# 2   USDT-USD      Tether USDt USD           1.0000    +0.0003   +0.03%
# 3    BNB-USD              BNB USD           382.06      +7.05   +1.88%
# 4    SOL-USD           Solana USD           104.15      +4.20   +4.20%
# 5    XRP-USD              XRP USD         0.545149  +0.010373   +1.94%
# 6  STETH-USD  Lido Staked ETH USD         2,986.06     +65.05   +2.23%
# 7   USDC-USD         USD Coin USD           1.0001    +0.0002   +0.02%
# 8    ADA-USD          Cardano USD         0.596379  +0.013325   +2.29%
# 9   AVAX-USD        Avalanche USD            36.79      +0.90   +2.50%
#
#   Market Cap Volume in Currency (Since 0:00 UTC) Volume in Currency (24Hr)  \
# 0     1.013T                             15.218B                   15.218B
# ...

# %%
data.to_csv(r'/Users/apple/Desktop/test.csv', index=False)

# %%
import re
import pandas as pd
import numpy as np

# Define a function to convert market cap values
def convert_market_cap(value):
    # Regular expression to capture numeric part and multiplier
    match = re.match(r'([\d.]+)\s*([BMT]?)', str(value))
    if match:
        numeric_part = float(match.group(1))
        multiplier = match.group(2)
        if multiplier == 'M':
            return numeric_part / 1e3  # Convert million to billion
        elif multiplier == 'T':
            return numeric_part / 1e3 # Convert trillion to billion
        else:
            return numeric_part  # No conversion needed for billion
    else:
        return np.nan  # Return NaN for invalid values


data['Market Cap'] = data['Market Cap'].apply(convert_market_cap)

# %%
def convert_Volume_in_Currency_Since_0(value):
    match = re.match(r'([\d.]+)\s*([BMT]?)', str(value))
    if match:
        numeric_part = float(match.group(1))
        multiplier = match.group(2)
        if multiplier == 'M':
            return numeric_part / 1e3  
        elif multiplier == 'T':
            return numeric_part / 1e6 
        else:
            return numeric_part 
    else:
        return np.nan 

data['Volume in Currency (Since 0:00 UTC)'] = data['Volume in Currency (Since 0:00 UTC)'].apply(convert_Volume_in_Currency_Since_0)

# %%
data
# Out:
#           Symbol                   Name Price (Intraday)       Change  \
# 0        BTC-USD            Bitcoin USD        51,605.39      +793.00
# 1        ETH-USD           Ethereum USD         2,991.34       +66.01
# 2       USDT-USD        Tether USDt USD           1.0000      +0.0003
# 3        BNB-USD                BNB USD           382.06        +7.05
# 4        SOL-USD             Solana USD           104.15        +4.20
# 5        XRP-USD                XRP USD         0.545149    +0.010373
# 6      STETH-USD    Lido Staked ETH USD         2,986.06       +65.05
# 7       USDC-USD           USD Coin USD           1.0001      +0.0002
# 8        ADA-USD            Cardano USD         0.596379    +0.013325
# 9       AVAX-USD          Avalanche USD            36.79        +0.90
# 10      DOGE-USD           Dogecoin USD         0.086097    +0.001948
# 11       TRX-USD               TRON USD         0.137565    -0.000625
# ...

# %%
data.drop(['52 Week Range','Day Chart'], axis=1, inplace=True)

# %%
data.to_csv(r'/Users/apple/Desktop/webscrape_of_crypto_cleaned.csv', index=False)
